# %%
import pandas as pd 
import numpy as np
import wordcloud 
import string 
import nltk; 
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download([
    "names",
    "stopwords",
    "state_union",
    "twitter_samples",
    "movie_reviews",
    "averaged_perceptron_tagger",
    "vader_lexicon",
    "punkt",])
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package names to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package names is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package state_union to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package state_union is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shchinthak/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
news = pd.read_csv('../../data/00-raw-data/long_covid_news_raw.csv')
text = news['title'].tolist()
text.append(news['content'].tolist())
text = ' '.join([str(elem) for elem in text])

# %%
text
# Out:
# 'About 18 million US adults have had long COVID, CDC report finds Has the risk of getting long covid been overestimated? Tests may be able to identify prolonged COVID symptoms in the future: Scientists Why Aren\'t Disabled Astronauts Exploring Space? Long Covid: MRI scans reveal new clues to symptoms [Removed] "Long colds" may exist, researchers find while studying long COVID Nearly 9 million Americans have long COVID, CDC says [Removed] [Removed] [Removed] [Removed] Long COVID has affected nearly 7% of U.S. adults, CDC survey data finds What to do if you think your child has long COVID How To Cure \'Brain Fog\' Using These Super Easy Expert Tips [Removed] Florida surgeon general rejects FDA guidance, urges people under 65 not to get Covid booster [Removed] Long Covid study: Scans reveal multiple organ abnormalities months after infection Have a cold you can’t seem to shake? Long COVID is a thing—and ‘long cold’ may be too [Removed] A long Covid blood test is possible, new research suggests [Removed] [Removed] Long-COVID may not be the only long-term respiratory illness - study Rapid tests are less accessible even as COVID wave ramps up across Canada, doctors say It\'s not just long Covid: Symptoms can linger after other illnesses, leading to \'long colds\' [Removed] Long COVID: Can creatine supplements help improve fatigue? Long colds vs. long COVID: The differences, similarities in symptoms Up to 10% of Quebec health-care workers have experienced long COVID: study What are the risks of catching COVID over and over? It\'s complicated, researchers say [Removed] Instagram\'s Threads never wanted to be a platform for hard news or politics. Now it\'s blocking searches about COVID-19. Rehab programs can improve quality of life for patients struggling with long COVID: research [Removed] A dose of creatine may help relieve long Covid symptoms Incidence of long COVID \'strikingly low\' in children, Alberta researchers find [Removed] [Removed] [Removed] Social Media Drops the ‘Digital Town Square’ Routine Canadians are travelling to Mexico for Lyme disease treatments. That worries health experts [Removed] \'Long colds\' show prolonged symptoms similar to long Covid, claims study New research discovers blood substances vital for identifying long Covid patients Former university athlete says COVID stopped him from running — wants people to mask again [Removed] [Removed] [Removed] [Removed] [Removed] Yes, the new Covid vaccine costs money.\xa0Yes, you should get it. Regardless of Age, Joe Biden Is Still the Right Person To Lead Our Country | Opinion Sore throat, then congestion: Common Covid symptoms follow a pattern now, doctors say [Removed] [Removed] As Covid cases rise, what to know about Paxlovid Is America Going Too Far on COVID Vaccines? Government shutdown looms and David McCallum dies: Morning Rundown What is POTS? This strange disorder has doubled since the pandemic Researchers discover pre-existing heart conditions can worsen due to body\'s inflammatory response to Covid Nagorno-Karabakh: aid arrives amidst worsening conditions \'COVID was never gone\': As cases rise in B.C., so do worries about normalizing the virus Putin May Break UN Pact Russia Voted to Enact Aaron Rodgers Challenges \'Mr. Pfizer\' Travis Kelce to Duel With RFK Jr. Republicans\' Belief COVID Is Getting Worse Is Growing Fast When and where can you get the updated COVID booster? And who needs one? What you need to know, according to experts What to expect from the jobs report What to expect from Friday\'s jobs report People who’ve had Covid at least 5 times describe how the illness changed with each reinfection Family of ill teen say they were silenced by courts Are COVID Boosters Safe? What the Science Says Britain\'s COVID-19 response inquiry enters second phase with political decisions in the spotlight The new COVID-19 vaccines are here for the fall Self-Silencing Is Making Women Sick Why the new COVID shot is a game-changer (and why the term ‘booster’ is  ...

# %%
# #FILTER OUT UNWANTED CHARACTERS
new_text=""
for character in text:
    if character in string.printable:
        new_text+=character
text=new_text
print(text)

# #FILTER OUT UNWANTED WORDS
new_text=""
for word in nltk.tokenize.word_tokenize(text):
    if word not in nltk.corpus.stopwords.words('english'):
        if word in [".",",","!","?",":",";"]:
            #remove the last space
            new_text=new_text[0:-1]+word+" "
        else: #add a space
            new_text+=word.lower()+" "
text=new_text
print(text)
# Out:
# About 18 million US adults have had long COVID, CDC report finds Has the risk of getting long covid been overestimated? Tests may be able to identify prolonged COVID symptoms in the future: Scientists Why Aren't Disabled Astronauts Exploring Space? Long Covid: MRI scans reveal new clues to symptoms [Removed] "Long colds" may exist, researchers find while studying long COVID Nearly 9 million Americans have long COVID, CDC says [Removed] [Removed] [Removed] [Removed] Long COVID has affected nearly 7% of U.S. adults, CDC survey data finds What to do if you think your child has long COVID How To Cure 'Brain Fog' Using These Super Easy Expert Tips [Removed] Florida surgeon general rejects FDA guidance, urges people under 65 not to get Covid booster [Removed] Long Covid study: Scans reveal multiple organ abnormalities months after infection Have a cold you cant seem to shake? Long COVID is a thingand long cold may be too [Removed] A long Covid blood test is possible, new research suggests [Removed] [Removed] Long-COVID may not be the only long-term respiratory illness - study Rapid tests are less accessible even as COVID wave ramps up across Canada, doctors say It's not just long Covid: Symptoms can linger after other illnesses, leading to 'long colds' [Removed] Long COVID: Can creatine supplements help improve fatigue? Long colds vs. long COVID: The differences, similarities in symptoms Up to 10% of Quebec health-care workers have experienced long COVID: study What are the risks of catching COVID over and over? It's complicated, researchers say [Removed] Instagram's Threads never wanted to be a platform for hard news or politics. Now it's blocking searches about COVID-19. Rehab programs can improve quality of life for patients struggling with long COVID: research [Removed] A dose of creatine may help relieve long Covid symptoms Incidence of long COVID 'strikingly low' in children, Alberta researchers find [Removed] [Removed] [Removed] Social Media Drops the Digital Town Square Routine Canadians are travelling to Mexico for Lyme disease treatments. That worries health experts [Removed] 'Long colds' show prolonged symptoms similar to long Covid, claims study New research discovers blood substances vital for identifying long Covid patients Former university athlete says COVID stopped him from running  wants people to mask again [Removed] [Removed] [Removed] [Removed] [Removed] Yes, the new Covid vaccine costs money.Yes, you should get it. Regardless of Age, Joe Biden Is Still the Right Person To Lead Our Country | Opinion Sore throat, then congestion: Common Covid symptoms follow a pattern now, doctors say [Removed] [Removed] As Covid cases rise, what to know about Paxlovid Is America Going Too Far on COVID Vaccines? Government shutdown looms and David McCallum dies: Morning Rundown What is POTS? This strange disorder has doubled since the pandemic Researchers discover pre-existing heart conditions can worsen due to body's inflammatory response to Covid Nagorno-Karabakh: aid arrives amidst worsening conditions 'COVID was never gone': As cases rise in B.C., so do worries about normalizing the virus Putin May Break UN Pact Russia Voted to Enact Aaron Rodgers Challenges 'Mr. Pfizer' Travis Kelce to Duel With RFK Jr. Republicans' Belief COVID Is Getting Worse Is Growing Fast When and where can you get the updated COVID booster? And who needs one? What you need to know, according to experts What to expect from the jobs report What to expect from Friday's jobs report People whove had Covid at least 5 times describe how the illness changed with each reinfection Family of ill teen say they were silenced by courts Are COVID Boosters Safe? What the Science Says Britain's COVID-19 response inquiry enters second phase with political decisions in the spotlight The new COVID-19 vaccines are here for the fall Self-Silencing Is Making Women Sick Why the new COVID shot is a game-changer (and why the term booster is obsolete) DeSantis administration ad ...
# about 18 million us adults long covid, cdc report finds has risk getting long covid overestimated? tests may able identify prolonged covid symptoms future: scientists why are n't disabled astronauts exploring space? long covid: mri scans reveal new clues symptoms [ removed ] `` long colds '' may exist, researchers find studying long covid nearly 9 million americans long covid, cdc says [ removed ] [ removed ] [ removed ] [ removed ] long covid affected nearly 7 % u.s. adults, cdc survey data finds what think child long covid how to cure 'brain fog ' using these super easy expert tips [ removed ] florida surgeon general rejects fda guidance, urges people 65 get covid booster [ removed ] long covid study: scans reveal multiple organ abnormalities months infection have cold cant seem shake? long covid thingand long cold may [ removed ] a long covid blood test possible, new research suggests [ removed ] [ removed ] long-covid may long-term respiratory illness - study rapid tests less accessible even covid wave ramps across canada, doctors say it 's long covid: symptoms linger illnesses, leading 'long colds ' [ removed ] long covid: can creatine supplements help improve fatigue? long colds vs. long covid: the differences, similarities symptoms up 10 % quebec health-care workers experienced long covid: study what risks catching covid? it 's complicated, researchers say [ removed ] instagram 's threads never wanted platform hard news politics. now 's blocking searches covid-19. rehab programs improve quality life patients struggling long covid: research [ removed ] a dose creatine may help relieve long covid symptoms incidence long covid 'strikingly low ' children, alberta researchers find [ removed ] [ removed ] [ removed ] social media drops digital town square routine canadians travelling mexico lyme disease treatments. that worries health experts [ removed ] 'long colds ' show prolonged symptoms similar long covid, claims study new research discovers blood substances vital identifying long covid patients former university athlete says covid stopped running wants people mask [ removed ] [ removed ] [ removed ] [ removed ] [ removed ] yes, new covid vaccine costs money.yes, get. regardless age, joe biden is still right person to lead our country | opinion sore throat, congestion: common covid symptoms follow pattern, doctors say [ removed ] [ removed ] as covid cases rise, know paxlovid is america going too far covid vaccines? government shutdown looms david mccallum dies: morning rundown what pots? this strange disorder doubled since pandemic researchers discover pre-existing heart conditions worsen due body 's inflammatory response covid nagorno-karabakh: aid arrives amidst worsening conditions 'covid never gone ': as cases rise b.c., worries normalizing virus putin may break un pact russia voted enact aaron rodgers challenges 'mr. pfizer ' travis kelce duel with rfk jr. republicans ' belief covid is getting worse is growing fast when get updated covid booster? and needs one? what need know, according experts what expect jobs report what expect friday 's jobs report people whove covid least 5 times describe illness changed reinfection family ill teen say silenced courts are covid boosters safe? what science says britain 's covid-19 response inquiry enters second phase political decisions spotlight the new covid-19 vaccines fall self-silencing is making women sick why new covid shot game-changer ( term booster obsolete ) desantis administration advises covid shots florida residents 65 13 innovators shaping future health [ removed ] [ removed ] nobel peace prize winner announced bedbug infestation fears: morning rundown what need know covid new variant rises health human services department awards clinics treating long covid patients $ 45 million [ removed ] covid cases rising. heres refresher everything forgot. long covid is real. now evidence is piling up. government relaunches free covid-19 tests website, heres book | details ba ...

# %%
def generate_word_cloud(my_text):
    from wordcloud import WordCloud, STOPWORDS
    import matplotlib.pyplot as plt
    # exit()
    # Import package
    # Define a function to plot word cloud
    def plot_cloud(wordcloud):
        # Set figure size
        plt.figure(figsize=(40, 30))
        # Display image
        plt.imshow(wordcloud) 
        # No axis details
        plt.axis("off");

    # Generate word cloud
    wordcloud = WordCloud(
        width = 3000,
        height = 2000, 
        random_state=1, 
        background_color='salmon', 
        colormap='Pastel1', 
        collocations=False,
        stopwords = STOPWORDS).generate(my_text)
    plot_cloud(wordcloud)
    plt.show()

# %%
generate_word_cloud(text)

# %%
my_file = open('../../data/00-raw-data/white_house_statement_raw.txt', "r") 
  
# reading the file 
data = my_file.read() 
  
# replacing end of line('/n') with ' ' and 
# splitting the text it further when '.' is seen. 
wh_text = data.replace('\n', ' ')
  
# printing the data 
print(wh_text) 
my_file.close()
# Out:
# Memorandum on Addressing the Long-Term Effects of COVID-⁠19 April 05, 2022 MEMORANDUM FOR THE HEADS OF EXECUTIVE DEPARTMENTS AND AGENCIES  SUBJECT:      Addressing the Long-Term Effects of COVID-19   By the authority vested in me as President by the Constitution and the laws of the United States of America, it is hereby ordered as follows:  Section 1.  Policy.  My Administration has made combating the coronavirus disease 2019 (COVID-19) pandemic, and guiding the Nation through the worst public health crisis in more than a century, our top priority.  When I came into office, COVID-19 was wreaking havoc on our country — closing our businesses, keeping our kids out of school, and forcing us into isolation.  Today, America has the tools to protect against COVID-19 and to dramatically decrease its risks.  We move towards a future in which COVID-19 does not disrupt our daily lives and is something we prevent, protect against, and treat.  As we chart the path forward, we remember the more than 950,000 people in the United States lost to COVID-19.  They were beloved parents, grandparents, children, siblings, spouses, neighbors, and friends.  More than 200,000 children in the United States have lost a parent or caregiver to the disease.  Each soul is irreplaceable, and the families and communities left behind are still reeling from profound loss.  Many families and communities have already received support from Federal programs that help with the loss they have experienced.  As we move forward, we commit to ensuring that families and communities can access these support programs and connect to resources they may need to help with their healing, health, and well-being.  At the same time, many of our family members, neighbors, and friends continue to experience negative long-term effects of COVID-19.  Many individuals report debilitating, long-lasting effects of having been infected with COVID-19, often called “long COVID.”  These symptoms can happen to anyone who has had COVID-19 — including individuals across ages, races, genders, and ethnicities; individuals with or without disabilities; individuals with or without underlying health conditions; and individuals whether or not they had initial symptoms.  Individuals experiencing long COVID report experiencing new or recurrent symptoms, which can include anxiety and depression, fatigue, shortness of breath, difficulty concentrating, heart palpitations, disordered sleep, chest and joint pain, headaches, and other symptoms.  These symptoms can persist long after the acute COVID-19 infection has resolved.  Even young people and otherwise healthy people have reported long COVID symptoms that last for many months.  These symptoms may be affecting individuals’ ability to work, conduct daily activities, engage in educational activities, and participate in their communities.  Our world-class research and public health organizations have begun the difficult work of understanding these new conditions, their causes, and potential prevention and treatment options.  Our health care and support programs are working to help meet the needs of individuals experiencing the lasting effects of COVID-19.  To organize the Federal Government’s response, executive departments and agencies (agencies) must work together to use the expertise, resources, and benefit programs of the Federal Government to ensure that we are accelerating scientific progress and providing individuals with the support and services they need.  In addition, the American public is grappling with a mental health crisis exacerbated by the pandemic. Too many have felt the effects of social isolation, sickness, economic insecurity, increased caregiver burdens, and grief.  My Administration has made significant investments in mental health as well as substance use disorder prevention, treatment, and recovery support for the American public, including by expanding access to community-based behavioral health services.  We are committed to advanci ...

# %%
# #FILTER OUT UNWANTED CHARACTERS
new_text=""
for character in wh_text:
    if character in string.printable:
        new_text+=character
wh_text=new_text
print(wh_text)

# #FILTER OUT UNWANTED WORDS
new_text=""
for word in nltk.tokenize.word_tokenize(wh_text):
    if word not in nltk.corpus.stopwords.words('english'):
        if word in [".",",","!","?",":",";","(",")","()"]:
            #remove the last space
            new_text=new_text[0:-1]+word+" "
        else: #add a space
            new_text+=word.lower()+" "
wh_text=new_text
print(wh_text)
# Out:
# Memorandum on Addressing the Long-Term Effects of COVID-19 April 05, 2022 MEMORANDUM FOR THE HEADS OF EXECUTIVE DEPARTMENTS AND AGENCIES  SUBJECT:      Addressing the Long-Term Effects of COVID-19   By the authority vested in me as President by the Constitution and the laws of the United States of America, it is hereby ordered as follows:  Section 1.  Policy.  My Administration has made combating the coronavirus disease 2019 (COVID-19) pandemic, and guiding the Nation through the worst public health crisis in more than a century, our top priority.  When I came into office, COVID-19 was wreaking havoc on our country  closing our businesses, keeping our kids out of school, and forcing us into isolation.  Today, America has the tools to protect against COVID-19 and to dramatically decrease its risks.  We move towards a future in which COVID-19 does not disrupt our daily lives and is something we prevent, protect against, and treat.  As we chart the path forward, we remember the more than 950,000 people in the United States lost to COVID-19.  They were beloved parents, grandparents, children, siblings, spouses, neighbors, and friends.  More than 200,000 children in the United States have lost a parent or caregiver to the disease.  Each soul is irreplaceable, and the families and communities left behind are still reeling from profound loss.  Many families and communities have already received support from Federal programs that help with the loss they have experienced.  As we move forward, we commit to ensuring that families and communities can access these support programs and connect to resources they may need to help with their healing, health, and well-being.  At the same time, many of our family members, neighbors, and friends continue to experience negative long-term effects of COVID-19.  Many individuals report debilitating, long-lasting effects of having been infected with COVID-19, often called long COVID.  These symptoms can happen to anyone who has had COVID-19  including individuals across ages, races, genders, and ethnicities; individuals with or without disabilities; individuals with or without underlying health conditions; and individuals whether or not they had initial symptoms.  Individuals experiencing long COVID report experiencing new or recurrent symptoms, which can include anxiety and depression, fatigue, shortness of breath, difficulty concentrating, heart palpitations, disordered sleep, chest and joint pain, headaches, and other symptoms.  These symptoms can persist long after the acute COVID-19 infection has resolved.  Even young people and otherwise healthy people have reported long COVID symptoms that last for many months.  These symptoms may be affecting individuals ability to work, conduct daily activities, engage in educational activities, and participate in their communities.  Our world-class research and public health organizations have begun the difficult work of understanding these new conditions, their causes, and potential prevention and treatment options.  Our health care and support programs are working to help meet the needs of individuals experiencing the lasting effects of COVID-19.  To organize the Federal Governments response, executive departments and agencies (agencies) must work together to use the expertise, resources, and benefit programs of the Federal Government to ensure that we are accelerating scientific progress and providing individuals with the support and services they need.  In addition, the American public is grappling with a mental health crisis exacerbated by the pandemic. Too many have felt the effects of social isolation, sickness, economic insecurity, increased caregiver burdens, and grief.  My Administration has made significant investments in mental health as well as substance use disorder prevention, treatment, and recovery support for the American public, including by expanding access to community-based behavioral health services.  We are committed to advancing thes ...
# memorandum addressing long-term effects covid-19 april 05, 2022 memorandum for the heads of executive departments and agencies subject: addressing long-term effects covid-19 by authority vested president constitution laws united states america, hereby ordered follows: section 1. policy. my administration made combating coronavirus disease 2019( covid-19) pandemic, guiding nation worst public health crisis century, top priority. when i came office, covid-19 wreaking havoc country closing businesses, keeping kids school, forcing us isolation. today, america tools protect covid-19 dramatically decrease risks. we move towards future covid-19 disrupt daily lives something prevent, protect, treat. as chart path forward, remember 950,000 people united states lost covid-19. they beloved parents, grandparents, children, siblings, spouses, neighbors, friends. more 200,000 children united states lost parent caregiver disease. each soul irreplaceable, families communities left behind still reeling profound loss. many families communities already received support federal programs help loss experienced. as move forward, commit ensuring families communities access support programs connect resources may need help healing, health, well-being. at time, many family members, neighbors, friends continue experience negative long-term effects covid-19. many individuals report debilitating, long-lasting effects infected covid-19, often called long covid. these symptoms happen anyone covid-19 including individuals across ages, races, genders, ethnicities; individuals without disabilities; individuals without underlying health conditions; individuals whether initial symptoms. individuals experiencing long covid report experiencing new recurrent symptoms, include anxiety depression, fatigue, shortness breath, difficulty concentrating, heart palpitations, disordered sleep, chest joint pain, headaches, symptoms. these symptoms persist long acute covid-19 infection resolved. even young people otherwise healthy people reported long covid symptoms last many months. these symptoms may affecting individuals ability work, conduct daily activities, engage educational activities, participate communities. our world-class research public health organizations begun difficult work understanding new conditions, causes, potential prevention treatment options. our health care support programs working help meet needs individuals experiencing lasting effects covid-19. to organize federal governments response, executive departments agencies( agencies) must work together use expertise, resources, benefit programs federal government ensure accelerating scientific progress providing individuals support services need. in addition, american public grappling mental health crisis exacerbated pandemic. too many felt effects social isolation, sickness, economic insecurity, increased caregiver burdens, grief. my administration made significant investments mental health well substance use disorder prevention, treatment, recovery support american public, including expanding access community-based behavioral health services. we committed advancing behavioral health efforts order better identify effects pandemic mental health, substance use, well-being, take steps address effects people serve. our nation continue protect public spare countless families deepest pain imaginable everybody part. today, numerous tools protect loved ones covid-19 vaccines tests, treatments, masks,. my administration recognizes toll pandemic american public commits redoubling efforts support american people addressing long-term effects covid-19 lives society. sec. 2. organizing government-wide response long-term effects covid-19.() the secretary health human services( secretary) shall coordinate government-wide response long-term effects covid-19. my administration harness full potential federal government, coordination public- private-sector partners, mount full effective response. the secretary shall report  ...

# %%
generate_word_cloud(wh_text)

# %%
with open('../../data/01-modified-data/long_covid_news_clean.txt', 'w') as file:
    # Write the list as a string with elements separated by spaces and add a newline at the end
    file.write(''.join(map(str, text)) + '\n')

# %%
with open('../../data/01-modified-data/white_house_statement_cleaned.txt', 'w') as file:
    # Write the list as a string with elements separated by spaces and add a newline at the end
    file.write(''.join(map(str, wh_text)) + '\n')
